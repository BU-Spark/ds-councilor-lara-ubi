# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_districts = gpd.read_file('data/City_Council_Districts_-_Effective_for_the_2023_Municipal_Election.geojson')

# %%
# df_places['geometry']
df_districts['geometry'].plot()
# Out:
# <AxesSubplot:>

# %%
df_tracts = gpd.read_file('data/cb_2021_25_tract_500k.geojson')
df_tracts = df_tracts.rename({'NAME': 'tract'}, axis=1)
df_tracts = df_tracts.query('NAMELSADCO == "Suffolk County"')
df_tracts = df_tracts[['tract', 'geometry']]

# %%
df_tracts
# Out:
#         tract                                           geometry
# 1190     1.01  POLYGON Z ((-71.13660 42.36016 0.00000, -71.13...
# 1191     1.02  POLYGON Z ((-71.16090 42.35863 0.00000, -71.15...
# 1192     2.01  POLYGON Z ((-71.16764 42.35379 0.00000, -71.16...
# 1193     2.02  POLYGON Z ((-71.16057 42.35267 0.00000, -71.16...
# 1194     3.01  POLYGON Z ((-71.17394 42.35340 0.00000, -71.17...
# ...       ...                                                ...
# 1420     9816  POLYGON Z ((-70.99939 42.38833 0.00000, -71.00...
# 1421     9817  POLYGON Z ((-71.07256 42.35544 0.00000, -71.07...
# 1422     9818  POLYGON Z ((-71.12572 42.31843 0.00000, -71.12...
# 1423     9819  POLYGON Z ((-71.18531 42.27950 0.00000, -71.18...
# 1424  9901.01  GEOMETRYCOLLECTION Z (POLYGON Z ((-71.02778 42...
#
# [235 rows x 2 columns]

# %%
df_tracts['geometry'].plot()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv(
    'data/ACSDP5Y2021.DP03_2023-04-16T204655/ACSDP5Y2021.DP03-Data.csv')

df1 = pd.read_csv('data/ACSDT5Y2021.B02001-2023-04-18T220527.csv')
df.dropna(inplace=True, axis='columns')
df1.dropna(inplace=True, axis='columns')
df1_t = df1.set_index('Label (Grouping)', drop=False).transpose()
df1_t.reset_index(inplace=True)
df1_t.head()
#df1.head()
# Out:
# Label (Grouping)                                              index  Total:  \
# 0                                                  Label (Grouping)  Total:
# 1                 Census Tract 1.01, Suffolk County, Massachuset...   1,824
# 2                 Census Tract 1.01, Suffolk County, Massachuset...    ±331
# 3                 Census Tract 1.02, Suffolk County, Massachuset...   3,706
# 4                 Census Tract 1.02, Suffolk County, Massachuset...    ±750
#
# Label (Grouping)      White alone      Black or African American alone  \
# 0                     White alone      Black or African American alone
# 1                           1,348                                  105
# 2                            ±326                                  ±90
# 3                           2,109                                  423
# 4                            ±788                                 ±240
#
# Label (Grouping)      American Indian and Alaska Native alone  \
# 0                     American Indian and Alaska Native alone
# 1                                                           0
# 2                                                         ±13
# 3                                                           0
# 4                                                         ±13
#
# Label (Grouping)      Asian alone  \
# 0                     Asian alone
# 1                             320
# 2                            ±151
# 3                             735
# 4                            ±267
#
# Label (Grouping)     Native Hawaiian and Other Pacific Islander alone  \
# 0                     Native Hawaiian and Other Pacific Islander...
# 1                                                                 0
# 2                                                               ±13
# 3                                                                 0
# 4                                                               ±13
#
# Label (Grouping)      Some other race alone      Two or more races:  \
# 0                     Some other race alone      Two or more races:
# 1                                        22                      29
# 2                                       ±25                     ±28
# 3                                       403                      36
# 4                                      ±306                     ±44
#
# Label (Grouping)          Two races including Some other race  \
# 0                         Two races including Some other race
# 1                                                           7
# 2                                                         ±11
# 3                                                           0
# 4                                                         ±13
#
# Label (Grouping)         Two races excluding Some other race, and three or more races
# 0                         Two races excluding Some other race, a...
# 1                                                                22
# 2                                                               ±26
# 3                                                                36
# 4                                                               ±44

# %%
import re

df['tract'] = (df['NAME']
    .map(lambda x: re.search(r'[^\d]*(\d+\.\d+|\d+)', x))
    .map(lambda x: x.group(1) if x != None else ''))

df1_t['tract'] = (df1_t['index']
    .map(lambda x: re.search(r'[^\d]*(\d+\.\d+|\d+)', x))
    .map(lambda x: x.group(1) if x != None else ''))

df1_new = df1_t.iloc[1::2]
df1_new.head()
# Out:
# Label (Grouping)                                              index Total:  \
# 1                 Census Tract 1.01, Suffolk County, Massachuset...  1,824
# 3                 Census Tract 1.02, Suffolk County, Massachuset...  3,706
# 5                 Census Tract 2.01, Suffolk County, Massachuset...  4,309
# 7                 Census Tract 2.02, Suffolk County, Massachuset...  4,094
# 9                 Census Tract 3.01, Suffolk County, Massachuset...  2,827
#
# Label (Grouping)     White alone     Black or African American alone  \
# 1                          1,348                                 105
# 3                          2,109                                 423
# 5                          2,914                                 301
# 7                          2,479                                 316
# 9                          2,026                                 209
#
# Label (Grouping)     American Indian and Alaska Native alone     Asian alone  \
# 1                                                          0             320
# 3                                                          0             735
# 5                                                          0             243
# 7                                                          0             406
# 9                                                          0             328
#
# Label (Grouping)     Native Hawaiian and Other Pacific Islander alone  \
# 1                                                                 0
# 3                                                                 0
# 5                                                                 0
# 7                                                                 0
# 9                                                                 0
#
# Label (Grouping)     Some other race alone     Two or more races:  \
# 1                                       22                     29
# 3                                      403                     36
# 5                                      418                    433
# 7                                      404                    489
# 9                                      123                    141
#
# Label (Grouping)         Two races including Some other race  \
# 1                                                          7
# 3                                                          0
# 5                                                         52
# 7                                                        285
# 9                                                         72
#
# Label (Grouping)         Two races excluding Some other race, and three or more races  \
# 1                                                                22
# 3                                                                36
# 5                                                               381
# 7                                                               204
# 9                                                                69
#
# Label (Grouping) tract
# 1                 1.01
# 3                 1.02
# 5                 2.01
# 7                 2.02
# 9                 3.01

# %%
white = df1_new.iloc[: , [2, -1]].copy() 
white.head()
# Out:
# Label (Grouping)     White alone tract
# 1                          1,348  1.01
# 3                          2,109  1.02
# 5                          2,914  2.01
# 7                          2,479  2.02
# 9                          2,026  3.01

# %%
df_tracts
# Out:
#         tract                                           geometry
# 1190     1.01  POLYGON Z ((-71.13660 42.36016 0.00000, -71.13...
# 1191     1.02  POLYGON Z ((-71.16090 42.35863 0.00000, -71.15...
# 1192     2.01  POLYGON Z ((-71.16764 42.35379 0.00000, -71.16...
# 1193     2.02  POLYGON Z ((-71.16057 42.35267 0.00000, -71.16...
# 1194     3.01  POLYGON Z ((-71.17394 42.35340 0.00000, -71.17...
# ...       ...                                                ...
# 1420     9816  POLYGON Z ((-70.99939 42.38833 0.00000, -71.00...
# 1421     9817  POLYGON Z ((-71.07256 42.35544 0.00000, -71.07...
# 1422     9818  POLYGON Z ((-71.12572 42.31843 0.00000, -71.12...
# 1423     9819  POLYGON Z ((-71.18531 42.27950 0.00000, -71.18...
# 1424  9901.01  GEOMETRYCOLLECTION Z (POLYGON Z ((-71.02778 42...
#
# [235 rows x 2 columns]

# %%
df_analysis = df[['tract', 'DP03_0128PE']].merge(df_tracts, left_on='tract', right_on='tract')
df1_analysis = white.merge(df_tracts, left_on='tract', right_on='tract')
df1_analysis
# Out:
#         White alone    tract  \
# 0             1,348     1.01
# 1             2,109     1.02
# 2             2,914     2.01
# 3             2,479     2.02
# 4             2,026     3.01
# ..              ...      ...
# 230               0     9816
# 231               0     9817
# 232              10     9818
# 233               0     9819
# 234               0  9901.01
#
#                                               geometry
# 0    POLYGON Z ((-71.13660 42.36016 0.00000, -71.13...
# 1    POLYGON Z ((-71.16090 42.35863 0.00000, -71.15...
# 2    POLYGON Z ((-71.16764 42.35379 0.00000, -71.16...
# 3    POLYGON Z ((-71.16057 42.35267 0.00000, -71.16...
# 4    POLYGON Z ((-71.17394 42.35340 0.00000, -71.17...
# ..                                                 ...
# 230  POLYGON Z ((-70.99939 42.38833 0.00000, -71.00...
# 231  POLYGON Z ((-71.07256 42.35544 0.00000, -71.07...
# 232  POLYGON Z ((-71.12572 42.31843 0.00000, -71.12...
# 233  POLYGON Z ((-71.18531 42.27950 0.00000, -71.18...
# 234  GEOMETRYCOLLECTION Z (POLYGON Z ((-71.02778 42...
#
# [235 rows x 3 columns]

# %%
df1_analysis = gpd.GeoDataFrame(df1_analysis)
# df_analysis.dropna(subset=['DP03_0128PE'], axis=0)
# df_analysis.fillna(0.0)

df1_analysis[1] = pd.to_numeric(
    df1_analysis[df1_analysis.columns[0]], errors='coerce')

df1_analysis.dropna()

# df_analysis['geometry'].plot()
# with plt.style.context(("seaborn", "ggplot")):
df1_analysis.plot(df1_analysis[df1_analysis.columns[0]], legend=True, colormap='inferno')

# df_analysis.to_file('data/test.geojson')
# Out:
# /home/sana/.local/lib/python3.8/site-packages/geopandas/plotting.py:642: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   warnings.warn(
# <AxesSubplot:>

# %%
df_analysis = gpd.GeoDataFrame(df_analysis)
# df_analysis.dropna(subset=['DP03_0128PE'], axis=0)
# df_analysis.fillna(0.0)

df_analysis['DP03_0128PE'] = pd.to_numeric(
    df_analysis['DP03_0128PE'], errors='coerce')

df_analysis.dropna()

# df_analysis['geometry'].plot()
# with plt.style.context(("seaborn", "ggplot")):
df_analysis.plot("DP03_0128PE", legend=True, colormap='inferno')

# df_analysis.to_file('data/test.geojson')
# Out:
# /home/sana/.local/lib/python3.8/site-packages/geopandas/plotting.py:642: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   warnings.warn(
# <AxesSubplot:>

# %%
df_tracts['geometry'].plot()
# Out:
# <AxesSubplot: >
