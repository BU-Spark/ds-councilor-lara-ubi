# %%
import pandas as pd

df = pd.read_csv('./data/SNAP.csv')
df.head(10)
# Out:
#                                     Label (Grouping)  \
# 0                                         Households
# 1      With one or more people in the household 6...
# 2       No people in the household 60 years and over
# 3                                     HOUSEHOLD TYPE
# 4                              Married-couple family
# 5                                      Other family:
# 6                Male householder, no spouse present
# 7              Female householder, no spouse present
# 8                               Nonfamily households
# 9                       With children under 18 years
#
#   Boston city, Massachusetts!!Total!!Estimate  \
# 0                                     271,941
# 1                                      85,631
# 2                                     186,310
# 3                                         NaN
# 4                                      74,624
# 5                                      46,912
# 6                                      10,437
# ...

# %%
def parse_int(s):
    return int(''.join(list(filter(str.isdigit, s))))

# %%
parse_int(df.iloc[0,5]) #Number of SNAP recipients in boston
# Out:
# 54633

# %%
df1 = pd.read_csv('./data/hudPicture2021_650930.csv')
df1.head()
# Out:
#    Summary level   Program  label   Program.1 Sub-program  Name     Code  \
# 0        8   HUD  Programs      1  BOSTONCITY          ma   NaN  2507000
#
#    Subsidizedunitsavailable  %Occupied   ...  PLACE  Latitude  Longitude  \
# 0                     49690          93  ...   7000       NaN        NaN
#
#    State  PHATotalUnits   HAcategory   %WhiteHispanic   %WhiteNon-Hispanic   \
# 0     MA             NaN          NaN               19                   17
#
#    %MultipleRace   %OtherHispanic
# 0               0                7
#
# [1 rows x 72 columns]

# %%
df1.iloc[0][15] #Number of housing assisting recepients
# Out:
# 92100
