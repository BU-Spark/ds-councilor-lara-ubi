# %%
import pandas as pd

data_df = pd.read_excel('./Comparision_SNAP_years.xlsx', sheet_name="Sheet1")

# %%
data_df.dropna(axis='columns')
# Out:
#    Year  Households-Receiving SNAP  All households -Not Receiving SNAP  \
# 0  2015                      0.192                               0.808
# 1  2016                      0.191                               0.809
# 2  2017                      0.180                               0.820
# 3  2018                      0.185                               0.815
# 4  2019                      0.174                               0.826
# 5  2020                      0.168                               0.832
# 6  2021                      0.201                               0.799
#
#    households<60 receiving  households<60 not receiving  \
# 0                    0.166                        0.834
# 1                    0.162                        0.838
# 2                    0.153                        0.847
# 3                    0.149                        0.851
# 4                    0.140                        0.860
# 5                    0.134                        0.866
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

plt.plot(data_df["Year"], 100*data_df["Households-Receiving SNAP"])
plt.ylim(10, 30)
# add labels and title to the plot
plt.xlabel("Year")
plt.ylabel("% of Households Receiving SNAP")
plt.title("Trend of Households Receiving SNAP over the Years")

# show the plot
plt.show()

# %%
data_df["below poverty receiving"]
# Out:
# 0    0.501
# 1    0.512
# 2    0.491
# 3    0.509
# 4    0.503
# 5    0.490
# 6    0.502
# Name: below poverty receiving, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

plt.plot(data_df["Year"], 100*data_df["below poverty receiving"])
plt.ylim(30, 70)
# add labels and title to the plot
plt.xlabel("Year")
plt.ylabel("% of below poverty receiving")
plt.title("Trend of Households Receiving SNAP over the Years")

# show the plot
plt.show()
