# %%
import pandas as pd

poverty_ethnicity_df = pd.read_excel('./5yrs_Income_Ethnicity.xlsx', sheet_name="Poverty_Ethnicity")
income_white_df = pd.read_excel('./5yrs_Income_Ethnicity.xlsx', sheet_name="White")
income_black_df = pd.read_excel('./5yrs_Income_Ethnicity.xlsx', sheet_name="Black")
income_american_indian_df = pd.read_excel('./5yrs_Income_Ethnicity.xlsx', sheet_name="American Indian")
income_asian_df = pd.read_excel('./5yrs_Income_Ethnicity.xlsx', sheet_name="Asian Alone")
income_hispanic_df = pd.read_excel('./5yrs_Income_Ethnicity.xlsx', sheet_name="Hispanic")

# %%
poverty_ethnicity_df.head()
# Out:
#                    Ethnicity  2021  2019  2018  2017  2016
# 0                      White   4.2   3.6   4.1   4.3   4.5
# 1  Black or African American  10.5  12.6  12.7  15.5  17.8
# 2                      Asian   7.9   6.0   6.7  11.3   9.8
# 3                      Other  16.7  13.7  19.1  19.7  19.5
# 4          Two or more races  13.6  13.7  12.0  15.0  12.4

# %%
poverty_ethnicity_df[2021] = pd.to_numeric(poverty_ethnicity_df[2021])
poverty_ethnicity_df[2019] = pd.to_numeric(poverty_ethnicity_df[2019])
poverty_ethnicity_df[2018] = pd.to_numeric(poverty_ethnicity_df[2018])
poverty_ethnicity_df[2017] = pd.to_numeric(poverty_ethnicity_df[2017])
poverty_ethnicity_df[2016] = pd.to_numeric(poverty_ethnicity_df[2016])

# %%
plt = poverty_ethnicity_df.plot.bar(x="Ethnicity", y=[2016, 2017, 2018, 2018, 2021], figsize=[20, 5])
plt.set_title("% population below poverty vs Ethnicity")
plt.set_xlabel("Ethnicity")
plt.set_ylabel("% population")
for container in plt.containers:
    plt.bar_label(plt.containers[0])
    plt.bar_label(plt.containers[1])
    plt.bar_label(plt.containers[2])
    plt.bar_label(plt.containers[3])
    plt.bar_label(plt.containers[4])

# %%
income_hispanic_df
# Out:
#                Income Ranges       2021  2021.1       2019  2019.1       2018  \
# 0          Less than $10,000   8.980510   16602   9.374579   15986  10.446414
# 1         $10,000 to $14,999   8.594828   15889   6.628354   11303   7.660430
# 2         $15,000 to $19,999   4.395052    8125   3.991790    6807   5.233758
# 3         $20,000 to $24,999   3.459244    6395   4.241020    7232   6.873227
# 4         $25,000 to $29,999   4.716364    8719   3.899721    6650   4.084898
# 5         $30,000 to $34,999   2.802555    5181   3.854567    6573   3.996975
# 6         $35,000 to $39,999   2.924805    5407   3.364316    5737   3.250217
# 7         $40,000 to $44,999   3.481963    6437   4.912476    8377   4.244332
# 8         $45,000 to $49,999   4.051020    7489   4.012901    6843   4.147031
# 9         $50,000 to $59,999   5.662990   10469   6.067732   10347   5.284753
# 10        $60,000 to $74,999   8.291907   15329   9.171089   15639   9.449954
# ...

# %%
income_hispanic_df['Income Ranges'] = income_hispanic_df['Income Ranges'].str.replace("to", "-")
income_hispanic_df = income_hispanic_df.round(1)

# %%
mod_income_hispanic_df = income_hispanic_df[0:4]
plt = mod_income_hispanic_df.plot.bar(x="Income Ranges", y=[2016, 2017, 2018, 2018, 2021], figsize=[20, 5])
plt.set_title("Income vs Population - Hispanic or Latino Ethnic group")
plt.set_xlabel("Income($)")
plt.set_ylabel("% population")
for container in plt.containers:
    plt.bar_label(plt.containers[0])
    plt.bar_label(plt.containers[1])
    plt.bar_label(plt.containers[2])
    plt.bar_label(plt.containers[3])
    plt.bar_label(plt.containers[4])

# %%
income_asian_df = income_asian_df.round(1)
income_american_indian_df = income_american_indian_df.round(1)
income_black_df = income_black_df.round(1)
income_white_df = income_white_df.round(1)

# %%
mod_income_asian_df = income_asian_df[0:4]
plt = mod_income_asian_df.plot.bar(x="Income Ranges", y=[2016, 2017, 2018, 2018, 2021], figsize=[20, 5])
plt.set_title("Income vs Population - Asian Ethnic group")
plt.set_xlabel("Income($)")
plt.set_ylabel("% population")
for container in plt.containers:
    plt.bar_label(plt.containers[0])
    plt.bar_label(plt.containers[1])
    plt.bar_label(plt.containers[2])
    plt.bar_label(plt.containers[3])
    plt.bar_label(plt.containers[4])

# %%
mod_income_american_indian_df = income_american_indian_df[0:4]
plt = mod_income_american_indian_df.plot.bar(x="Income Ranges", y=[2016, 2017, 2018, 2018, 2021], figsize=[20, 5])
plt.set_title("Income vs Population - American Indian and Alaska Native Ethnic group")
plt.set_xlabel("Income($)")
plt.set_ylabel("% population")
for container in plt.containers:
    plt.bar_label(plt.containers[0])
    plt.bar_label(plt.containers[1])
    plt.bar_label(plt.containers[2])
    plt.bar_label(plt.containers[3])
    plt.bar_label(plt.containers[4])

# %%
mod_income_black_df = income_black_df[0:4]
plt = mod_income_black_df.plot.bar(x="Income Ranges", y=[2016, 2017, 2018, 2018, 2021], figsize=[20, 5])
plt.set_title("Income vs Population - Black or African American Ethnic group")
plt.set_xlabel("Income($)")
plt.set_ylabel("% population")
for container in plt.containers:
    plt.bar_label(plt.containers[0])
    plt.bar_label(plt.containers[1])
    plt.bar_label(plt.containers[2])
    plt.bar_label(plt.containers[3])
    plt.bar_label(plt.containers[4])

# %%
mod_income_white_df = income_white_df[0:4]
plt = mod_income_white_df.plot.bar(x="Income Ranges", y=[2016, 2017, 2018, 2018, 2021], figsize=[20, 5])
plt.set_title("Income vs Population - White Ethnic group")
plt.set_xlabel("Income($)")
plt.set_ylabel("% population")
for container in plt.containers:
    plt.bar_label(plt.containers[0])
    plt.bar_label(plt.containers[1])
    plt.bar_label(plt.containers[2])
    plt.bar_label(plt.containers[3])
    plt.bar_label(plt.containers[4])
